# %%
import numpy as np
import tensorflow as tf
import os
import pickle
import matplotlib.pyplot as plt
from scipy import misc
from scipy.spatial import distance

# %matplotlib inline

# %% [markdown]
# # facenetのダウンロード
# - https://github.com/davidsandberg/facenet
# - クローンしたパスをfacenet_pathに
# - tensorflowのversionは1.2が必要
#
# # 訓練済みのモデルのダウンロード
# - [MS-Celeb-1Mで訓練したモデル](https://drive.google.com/file/d/0B5MzpY9kBtDVOTVnU3NIaUdySFE/edit)
# - ダウンロードしたパスをmodelに

# %%
facenet_path = '../../facenet/'
model = facenet_path + 'model/20170511-185253'
image_dir_basepath = './'

# %%
import sys
sys.path.append(facenet_path + 'src/')
import facenet
import align.detect_face

from PIL import Image

# %% [markdown]
# # 顔検出

# %%
image_size = 112
margin = 44
batch_size = 1000

# %%
talents = ['kanako','shiori','ayaka','momoka','reni']

for talent in talents:
    
    dir_name = '{}_image/'.format(talent)
    image_dirpath = os.path.abspath(image_dir_basepath + dir_name)
    image_filepaths = [os.path.join(image_dirpath, f) for f in os.listdir(image_dirpath) if not f == '.DS_Store']

    image_out_dirpath = './cropped_images_{}/'.format(talent)
    if not os.path.exists(image_out_dirpath):
            os.mkdir(image_out_dirpath)

    for image_filepath in image_filepaths:
        out_file_name = "crop_" + os.path.basename(image_filepath)
        if os.path.exists(os.path.join(image_out_dirpath,out_file_name)):
            print("exist!:",out_file_name)
            continue
        extracted_filepaths = []
        minsize = 20
        threshold = [0.6, 0.7, 0.7]
        factor = 0.709

        with tf.Graph().as_default():
            with tf.Session() as sess:
                pnet, rnet, onet = align.detect_face.create_mtcnn(sess, None)
                img = misc.imread(image_filepath)
                img_size = np.array(img.shape)[0:2]
                bounding_boxes, _ = align.detect_face.detect_face(img, minsize, pnet, rnet, onet,
                                                                  threshold, factor)
                if len(bounding_boxes) == 0:
                    continue
                det = bounding_boxes[0, :4]
                bb = np.zeros(4, dtype=np.int32)
                bb[0] = np.maximum(det[0]-margin/2, 0)
                bb[1] = np.maximum(det[1]-margin/2, 0)
                bb[2] = np.minimum(det[2]+margin/2, img_size[1])
                bb[3] = np.minimum(det[3]+margin/2, img_size[0])
                cropped = img[bb[1]:bb[3],bb[0]:bb[2],:]
                aligned = misc.imresize(cropped, (image_size, image_size), interp='bilinear')

                img = Image.fromarray(np.uint8(aligned))
                img.save(os.path.join(image_out_dirpath,out_file_name))

                #test (try only on one image)
                # plt.figure(figsize=(20, 10))
                # plt.subplot(1,3,1)
                # plt.imshow(img)
                # plt.subplot(1,3,2)
                # plt.imshow(cropped)
                # plt.subplot(1,3,3)
                # plt.imshow(aligned)
# Out:
# exist!: crop_kanako387.jpg
# exist!: crop_kanako393.jpg
# exist!: crop_kanako422.jpg
# exist!: crop_kanako344.jpg
# exist!: crop_kanako436.jpg
# exist!: crop_kanako378.jpg
# exist!: crop_kanako185.jpg
# exist!: crop_kanako191.jpg
# exist!: crop_kanako146.jpg
# exist!: crop_kanako152.jpg
# exist!: crop_kanako6.jpg
# exist!: crop_kanako23.jpg
# exist!: crop_kanako37.jpg
# exist!: crop_kanako230.jpg
# exist!: crop_kanako224.jpg
# exist!: crop_kanako218.jpg
# exist!: crop_kanako219.jpg
# exist!: crop_kanako225.jpg
# exist!: crop_kanako231.jpg
# exist!: crop_kanako36.jpg
# exist!: crop_kanako22.jpg
# exist!: crop_kanako7.jpg
# exist!: crop_kanako153.jpg
# exist!: crop_kanako147.jpg
# exist!: crop_kanako190.jpg
# exist!: crop_kanako184.jpg
# exist!: crop_kanako379.jpg
# exist!: crop_kanako437.jpg
# exist!: crop_kanako423.jpg
# exist!: crop_kanako345.jpg
# exist!: crop_kanako392.jpg
# exist!: crop_kanako386.jpg
# exist!: crop_kanako390.jpg
# exist!: crop_kanako384.jpg
# exist!: crop_kanako435.jpg
# exist!: crop_kanako353.jpg
# exist!: crop_kanako347.jpg
# exist!: crop_kanako421.jpg
# exist!: crop_kanako409.jpg
# exist!: crop_kanako192.jpg
# exist!: crop_kanako186.jpg
# exist!: crop_kanako145.jpg
# exist!: crop_kanako179.jpg
# exist!: crop_kanako5.jpg
# exist!: crop_kanako34.jpg
# exist!: crop_kanako20.jpg
# exist!: crop_kanako227.jpg
# exist!: crop_kanako233.jpg
# exist!: crop_kanako232.jpg
# exist!: crop_kanako226.jpg
# exist!: crop_kanako21.jpg
# exist!: crop_kanako35.jpg
# exist!: crop_kanako4.jpg
# exist!: crop_kanako178.jpg
# exist!: crop_kanako144.jpg
# exist!: crop_kanako150.jpg
# exist!: crop_kanako187.jpg
# exist!: crop_kanako193.jpg
# exist!: crop_kanako408.jpg
# exist!: crop_kanako346.jpg
# exist!: crop_kanako434.jpg
# exist!: crop_kanako385.jpg
# exist!: crop_kanako391.jpg
# exist!: crop_kanako418.jpg
# exist!: crop_kanako356.jpg
# exist!: crop_kanako430.jpg
# exist!: crop_kanako424.jpg
# exist!: crop_kanako342.jpg
# exist!: crop_kanako197.jpg
# exist!: crop_kanako168.jpg
# exist!: crop_kanako154.jpg
# exist!: crop_kanako140.jpg
# exist!: crop_kanako0.jpg
# exist!: crop_kanako19.jpg
# exist!: crop_kanako31.jpg
# exist!: crop_kanako25.jpg
# exist!: crop_kanako222.jpg
# exist!: crop_kanako236.jpg
# exist!: crop_kanako223.jpg
# exist!: crop_kanako24.jpg
# exist!: crop_kanako30.jpg
# exist!: crop_kanako18.jpg
# exist!: crop_kanako1.jpg
# exist!: crop_kanako141.jpg
# exist!: crop_kanako155.jpg
# exist!: crop_kanako169.jpg
# exist!: crop_kanako182.jpg
# exist!: crop_kanako196.jpg
# exist!: crop_kanako343.jpg
# exist!: crop_kanako431.jpg
# exist!: crop_kanako419.jpg
# exist!: crop_kanako380.jpg
# exist!: crop_kanako394.jpg
# exist!: crop_kanako382.jpg
# exist!: crop_kanako369.jpg
# exist!: crop_kanako341.jpg
# exist!: crop_kanako427.jpg
# exist!: crop_kanako433.jpg
# exist!: crop_kanako355.jpg
# exist!: crop_kanako180.jpg
# exist!: crop_kanako194.jpg
# exist!: crop_kanako143.jpg
# exist!: crop_kanako157.jpg
# exist!: crop_kanako3.jpg
# exist!: crop_kanako26.jpg
# exist!: crop_kanako32.jpg
# exist!: crop_kanako209.jpg
# exist!: crop_kanako235.jpg
# exist!: crop_kanako221.jpg
# exist!: crop_kanako220.jpg
# exist!: crop_kanako234.jpg
# exist!: crop_kanako208.jpg
# exist!: crop_kanako33.jpg
# exist!: crop_kanako27.jpg
# exist!: crop_kanako2.jpg
# exist!: crop_kanako156.jpg
# exist!: crop_kanako142.jpg
# exist!: crop_kanako195.jpg
# exist!: crop_kanako181.jpg
# exist!: crop_kanako432.jpg
# exist!: crop_kanako354.jpg
# exist!: crop_kanako340.jpg
# exist!: crop_kanako426.jpg
# exist!: crop_kanako368.jpg
# exist!: crop_kanako397.jpg
# exist!: crop_kanako383.jpg
# exist!: crop_kanako327.jpg
# exist!: crop_kanako441.jpg
# exist!: crop_kanako333.jpg
# exist!: crop_kanako125.jpg
# exist!: crop_kanako131.jpg
# exist!: crop_kanako83.jpg
# exist!: crop_kanako97.jpg
# exist!: crop_kanako40.jpg
# exist!: crop_kanako54.jpg
# exist!: crop_kanako68.jpg
# exist!: crop_kanako290.jpg
# exist!: crop_kanako284.jpg
# exist!: crop_kanako253.jpg
# exist!: crop_kanako247.jpg
# exist!: crop_kanako246.jpg
# exist!: crop_kanako252.jpg
# exist!: crop_kanako285.jpg
# exist!: crop_kanako291.jpg
# exist!: crop_kanako69.jpg
# exist!: crop_kanako55.jpg
# exist!: crop_kanako41.jpg
# exist!: crop_kanako96.jpg
# exist!: crop_kanako82.jpg
# exist!: crop_kanako118.jpg
# exist!: crop_kanako124.jpg
# exist!: crop_kanako332.jpg
# exist!: crop_kanako326.jpg
# exist!: crop_kanako330.jpg
# exist!: crop_kanako324.jpg
# exist!: crop_kanako132.jpg
# exist!: crop_kanako126.jpg
# exist!: crop_kanako94.jpg
# exist!: crop_kanako80.jpg
# exist!: crop_kanako57.jpg
# exist!: crop_kanako43.jpg
# exist!: crop_kanako287.jpg
# exist!: crop_kanako244.jpg
# exist!: crop_kanako250.jpg
# exist!: crop_kanako278.jpg
# exist!: crop_kanako251.jpg
# exist!: crop_kanako245.jpg
# exist!: crop_kanako292.jpg
# exist!: crop_kanako286.jpg
# exist!: crop_kanako42.jpg
# exist!: crop_kanako56.jpg
# exist!: crop_kanako81.jpg
# exist!: crop_kanako95.jpg
# exist!: crop_kanako127.jpg
# exist!: crop_kanako133.jpg
# exist!: crop_kanako319.jpg
# exist!: crop_kanako443.jpg
# exist!: crop_kanako325.jpg
# exist!: crop_kanako309.jpg
# exist!: crop_kanako335.jpg
# exist!: crop_kanako321.jpg
# exist!: crop_kanako447.jpg
# exist!: crop_kanako137.jpg
# exist!: crop_kanako123.jpg
# exist!: crop_kanako91.jpg
# exist!: crop_kanako85.jpg
# exist!: crop_kanako52.jpg
# exist!: crop_kanako46.jpg
# exist!: crop_kanako282.jpg
# exist!: crop_kanako296.jpg
# exist!: crop_kanako241.jpg
